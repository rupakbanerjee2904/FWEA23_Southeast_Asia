# %% [markdown]
# # Plotting histogram of he slow velocity of SE Asia excluding the KP

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

dpath=f'/media/rupak/Rupak_4TB/BACKUPS/MANUSCRIPTS_Rupak/SE_ASIA_MANU_DRAFTS/MERGED/Manu_figs_organised/text_fig/GitHub_upload/vertical_avg/files'
fdp=100  #shallowest depth
edp=220  #end of depth
fname=os.path.join(dpath,f'vertically_avg_Vs_{fdp}_to_{edp}_km_SE_Asia_WITHOUT_KP')  ##Input file
print(f"Reading {fname}")
print(f"")

##From the histogram there are a limited counts of >4.47 km/s. Lets see where those velo are
vs_hi_cut=4.47
vs_list=[]
with open (fname,'r')as fi:
    for li in fi:
        row=li.strip().split()
        vs=float(row[2])
        lon=float(row[0])
        lat=float(row[1])
        #print(f"lon:{lon} lat:{lat} vs:{vs}")
        if vs>vs_hi_cut:
            print(f"vs > {vs_hi_cut}:")
            print(f"lon:{lon} lat:{lat} vs:{vs}")
        vs_list.append(vs)
        
        
#array
vs_array=np.array(vs_list)

min_Vs=np.min(vs_array)
max_Vs=np.max(vs_array)
print(f"")
print(f"MinVs:{min_Vs}")
print(f"MaxVs:{max_Vs}")
div=0.01
bin=int((max_Vs-min_Vs)/div)
print(f"No of bin with an interval of {div} is {bin}")
print(f"")

#find the mean, median
mean=np.mean(vs_array)
median=np.median(vs_array)
print(f"The spatial avergae of the vertiaclly averaged Vs from {fdp} to {edp} is {mean}")

#histogram
plt.figure(figsize=(10,6))
plt.hist(vs_array, bins=bin, edgecolor='black')
plt.title(f"mean Vs distribution ({fdp}-{edp} km)")
plt.xlabel("mean Vs (km/s)", fontsize=18)
plt.ylabel("counts", fontsize=18)
plt.text(0.05, 0.95, f'minVs = {min_Vs:.3f}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))
plt.text(0.05, 0.88, f'maxVs = {max_Vs:.3f}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))
plt.text(0.7, 0.95, f'Spatial average = {mean:.3f}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))
plt.text(0.7, 0.88, f'median = {median:.3f}', transform=plt.gca().transAxes,
         fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.5))
#plt.savefig(os.path.join(dpath,f"hist_vertically_avg_Vs_{fdp}_to_{edp}_km_SE_Asia_WITHOUT_KP.ps"))
#plt.savefig(os.path.join(dpath,f"hist_vertically_avg_Vs_{fdp}_to_{edp}_km_SE_Asia_WITHOUT_KP.png"))
plt.show()
# Out:
# Reading /media/rupak/Rupak_4TB/BACKUPS/MANUSCRIPTS_Rupak/SE_ASIA_MANU_DRAFTS/MERGED/Manu_figs_organised/text_fig/GitHub_upload/vertical_avg/files/vertically_avg_Vs_100_to_220_km_SE_Asia_WITHOUT_KP
#
# vs > 4.47:
# lon:101.75 lat:16.499999999999996 vs:4.484616311701884
# vs > 4.47:
# lon:101.75 lat:16.749999999999996 vs:4.50447604539983
# vs > 4.47:
# lon:98.0 lat:16.999999999999996 vs:4.47351645662011
# vs > 4.47:
# lon:101.50000000000001 lat:16.999999999999996 vs:4.491216177386931
# vs > 4.47:
# lon:101.75 lat:16.999999999999996 vs:4.526485779715865
# vs > 4.47:
# lon:101.25 lat:17.249999999999996 vs:4.482946523181948
# vs > 4.47:
# lon:101.50000000000001 lat:17.249999999999996 vs:4.518962832637762
# vs > 4.47:
# lon:101.75 lat:17.249999999999996 vs:4.550993328273076
# vs > 4.47:
# lon:101.25 lat:17.499999999999996 vs:4.49845691253611
# vs > 4.47:
# lon:101.50000000000001 lat:17.499999999999996 vs:4.533552544919126
# vs > 4.47:
# lon:101.75 lat:17.499999999999996 vs:4.564801783293383
# vs > 4.47:
# lon:101.0 lat:17.749999999999996 vs:4.472715959502238
# vs > 4.47:
# lon:101.25 lat:17.749999999999996 vs:4.5003645213442125
# vs > 4.47:
# lon:101.50000000000001 lat:17.749999999999996 vs:4.53624701438854
# vs > 4.47:
# lon:101.75 lat:17.749999999999996 vs:4.567195601644352
# vs > 4.47:
# lon:101.25 lat:17.999999999999996 vs:4.491102702136039
# vs > 4.47:
# lon:101.50000000000001 lat:17.999999999999996 vs:4.518692368206966
# vs > 4.47:
# lon:101.75 lat:17.999999999999996 vs:4.552287768500688
# vs > 4.47:
# lon:101.25 lat:18.249999999999996 vs:4.4742773390596895
# vs > 4.47:
# lon:101.50000000000001 lat:18.249999999999996 vs:4.4964152247705895
# vs > 4.47:
# lon:101.75 lat:18.249999999999996 vs:4.527950710294732
# vs > 4.47:
# lon:101.75 lat:18.499999999999993 vs:4.4874726758769725
# vs > 4.47:
# lon:98.0 lat:20.249999999999996 vs:4.474565963010896
# vs > 4.47:
# lon:98.0 lat:20.499999999999996 vs:4.473962629798219
#
# MinVs:4.23242841720489
# MaxVs:4.567195601644352
# No of bin with an interval of 0.01 is 33
#
# The spatial avergae of the vertiaclly averaged Vs from 100 to 220 is 4.378162851848884
